# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, LinearRegression
from tqdm import tqdm
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_selector, ColumnTransformer
from sklearn.metrics import r2_score, root_mean_squared_error, mean_absolute_error
import os
os.chdir("D:/Training/Academy/ML(Python)/Datasets")

# %%
boston = pd.read_csv("Boston.csv")
X = boston.drop('medv', axis=1)
y = boston['medv']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.intercept_, lr.coef_
# Out:
# (38.10422593184809,
#  array([-1.15254380e-01,  5.05163648e-02,  2.73670712e-02,  7.30471064e-01,
#         -1.89833026e+01,  4.03133215e+00, -4.82896709e-03, -1.54999896e+00,
#          3.67470486e-01, -1.66700680e-02, -9.85758737e-01,  7.44544822e-03,
#         -4.59169535e-01]))

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
#ridge.intercept_, ridge.coef_
y_pred = ridge.predict(X_test)
mean_absolute_error(y_test, y_pred)
# Out:
# 3.071006801570943

# %% [markdown]
# Hyper-parameter Tuning

# %%
alphas = [0.001, 0.01, 0.1, 1, 1.5, 2.5, 5, 10]
scores = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(X_test)
    scores.append([a, mean_absolute_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=['alpha','score'])
df_scores.sort_values('score')
# Out:
#     alpha     score
# 3   1.000  3.071007
# 4   1.500  3.073661
# 5   2.500  3.082563
# 2   0.100  3.100479
# 6   5.000  3.102838
# 1   0.010  3.115621
# 0   0.001  3.117373
# 7  10.000  3.124733

# %% [markdown]
# #### Housing

# %%
housing = pd.read_csv("Housing.csv")
X, y = housing.drop('price', axis=1), housing['price']

# %%
ohe = OneHotEncoder(drop='first', sparse_output=False).set_output(transform='pandas')
col_trnf = ColumnTransformer([('OHE',ohe, make_column_selector(dtype_include=object) )],
                             remainder='passthrough',
                             verbose_feature_names_out=False)
col_trnf = col_trnf.set_output(transform='pandas')
X = col_trnf.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# %%
alphas = [0.001, 0.01, 0.1, 1, 1.5, 2.5, 5, 10]
scores = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(X_test)
    scores.append([a, mean_absolute_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=['alpha','score'])
df_scores.sort_values('score')
# Out:
#     alpha         score
# 6   5.000  11540.704019
# 7  10.000  11547.050792
# 5   2.500  11561.705728
# 4   1.500  11574.321775
# 3   1.000  11581.329165
# 2   0.100  11598.734394
# 1   0.010  11600.720198
# 0   0.001  11600.919547

# %%
np.arange(0.001, 15, 0.5)
# Out:
# array([1.0000e-03, 5.0100e-01, 1.0010e+00, 1.5010e+00, 2.0010e+00,
#        2.5010e+00, 3.0010e+00, 3.5010e+00, 4.0010e+00, 4.5010e+00,
#        5.0010e+00, 5.5010e+00, 6.0010e+00, 6.5010e+00, 7.0010e+00,
#        7.5010e+00, 8.0010e+00, 8.5010e+00, 9.0010e+00, 9.5010e+00,
#        1.0001e+01, 1.0501e+01, 1.1001e+01, 1.1501e+01, 1.2001e+01,
#        1.2501e+01, 1.3001e+01, 1.3501e+01, 1.4001e+01, 1.4501e+01])

# %%
np.linspace(0.001, 15, 20)
# Out:
# array([1.00000000e-03, 7.90421053e-01, 1.57984211e+00, 2.36926316e+00,
#        3.15868421e+00, 3.94810526e+00, 4.73752632e+00, 5.52694737e+00,
#        6.31636842e+00, 7.10578947e+00, 7.89521053e+00, 8.68463158e+00,
#        9.47405263e+00, 1.02634737e+01, 1.10528947e+01, 1.18423158e+01,
#        1.26317368e+01, 1.34211579e+01, 1.42105789e+01, 1.50000000e+01])

# %%
alphas = np.linspace(0.001, 15, 30)
scores = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(X_test)
    scores.append([a, mean_absolute_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=['alpha','score'])
df_scores.sort_values('score')
# Out:
#         alpha         score
# 13   6.724690  11533.141773
# 14   7.241897  11533.594498
# 12   6.207483  11534.960073
# 15   7.759103  11535.836907
# 11   5.690276  11537.338372
# 16   8.276310  11538.090680
# 10   5.173069  11539.838648
# 17   8.793517  11540.473661
# 9    4.655862  11542.469585
# 18   9.310724  11543.069034
# 8    4.138655  11545.706362
# 19   9.827931  11546.033928
# 20  10.345138  11549.539803
# 7    3.621448  11550.330033
# 21  10.862345  11554.077894
# 6    3.104241  11555.132271
# 22  11.379552  11558.573842
# 5    2.587034  11560.652845
# 23  11.896759  11563.301806
# 4    2.069828  11567.012927
# 24  12.413966  11568.585169
# 3    1.552621  11573.632906
# 25  12.931172  11573.824080
# 26  13.448379  11579.018930
# 2    1.035414  11580.805060
# 27  13.965586  11584.170118
# 28  14.482793  11589.278055
# 1    0.518207  11589.685277
# 29  15.000000  11594.343154
# 0    0.001000  11600.919547

# %% [markdown]
# #### Exp_Salaries

# %%
sals = pd.read_csv("Exp_Salaries.csv")
X, y = sals.drop('Salary', axis=1), sals['Salary']

# %%
ohe = OneHotEncoder(drop='first', sparse_output=False).set_output(transform='pandas')
col_trnf = ColumnTransformer([('OHE',ohe, make_column_selector(dtype_include=object) )],
                             remainder='passthrough',
                             verbose_feature_names_out=False)
col_trnf = col_trnf.set_output(transform='pandas')
X = col_trnf.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# %%
alphas = np.linspace(0.001, 15, 30)
scores = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X_train, y_train)
    y_pred = ridge.predict(X_test)
    scores.append([a, mean_absolute_error(y_test, y_pred)])
df_scores = pd.DataFrame(scores, columns=['alpha','score'])
df_scores.sort_values('score')
# Out:
#         alpha        score
# 0    0.001000  3035.260687
# 1    0.518207  3060.466741
# 2    1.035414  3078.726901
# 3    1.552621  3092.796290
# 4    2.069828  3104.036051
# 5    2.587034  3113.225194
# 6    3.104241  3120.855344
# 7    3.621448  3132.731545
# 8    4.138655  3144.433010
# 9    4.655862  3153.783976
# 10   5.173069  3161.290697
# 11   5.690276  3167.325916
# 12   6.207483  3177.043607
# 13   6.724690  3189.884086
# 14   7.241897  3201.353722
# 15   7.759103  3211.647556
# 16   8.276310  3220.924025
# 17   8.793517  3230.944881
# 18   9.310724  3244.318701
# 19   9.827931  3256.680018
# 20  10.345138  3268.133665
# 21  10.862345  3278.769895
# 22  11.379552  3288.666938
# 23  11.896759  3297.893010
# 24  12.413966  3306.507937
# 25  12.931172  3314.564445
# 26  13.448379  3322.109224
# 27  13.965586  3329.183797
# 28  14.482793  3335.825236
# 29  15.000000  3342.066762

# %% [markdown]
# `.get_dummies()`

# %%
pd.get_dummies(sals, drop_first=True)
# Out:
#     Salary  Years_Previous_Experience  Years Employed  Years_Education  \
# 0    32782                          1               0                7
# 1    32920                          3              15                9
# 2    29548                          6               5                1
# 3    39828                          6              18                5
# 4    31528                         11               3                3
# 5    38985                          7              18                9
# 6    41889                         16              22                7
# 7    38791                          4              21                5
# 8    28985                          1               0                4
# 9    24749                          2               6                0
# 10   35467                          6               3                6
# 11   35468                          5               9                4
# 12   29876                          0               2                3
# 13   43674                          9               6                4
# 14   36431                          4               9                4
# 15   26578                          6               0                2
# 16   36571                          1               6                4
# 17   56326                          3              12                8
# 18   23654                          0               0                0
# 19   36578                          4               4                8
# 20   37548                          9              19                4
# 21   53234                          0              25                6
# 22   54679                          3              20                6
# 23   47536                          5              15                6
# 24   31425                          6               7                5
# 25   65487                          0              27               12
# 26   46184                          3              20                4
# 27   54899                          5              12                8
# 28   34869                          5               7                4
# 29   35487                          2               8                2
# 30   26548                          1               5                0
# 31   34231                          2               6                6
# 32   39331                          3               9                6
# 33   36512                          6               6                4
# 34   68425                          2              25               12
# 35   36487                          5               6                2
# 36   34632                          4               5                4
# 37   46211                          5              14                6
# 38   51698                          6              18                6
# 39   69246                          3              22               10
# 40   48695                         19               6                8
# 41   34987                          6               9                2
# 42   35631                          4               6                4
# 43   39743                          6               9                5
# 44   41255                          4               9                6
# 45   26452                          3               1                2
#
#     Number_Supervised  Gender_Male  Department_B  Department_C  Department_D
# 0                   0         True         False         False         False
# 1                   4        False         False         False         False
# 2                   0         True         False         False         False
# 3                   5        False         False         False         False
# 4                   6         True         False         False         False
# 5                   5         True         False         False         False
# 6                   7         True         False         False         False
# 7                   9         True         False         False         False
# 8                   4        False         False         False         False
# 9                   1        False         False         False         False
# 10                  3        False          True         False         False
# 11                  5        False          True         False         False
# 12                  5        False          True         False         False
# 13                  2         True          True         False         False
# 14                  2        False          True         False         False
# 15                  2        False          True         False         False
# 16                  2         True          True         False         False
# 17                  6         True          True         False         False
# 18                  2        False         False          True         False
# 19                  8         True         False          True         False
# 20                  6         True         False          True         False
# 21                  3         True         False          True         False
# 22                  4        False         False          True         False
# 23                  4         True         False          True         False
# 24                  6        False         False          True         False
# 25                 44        False         False         False          True
# 26                  1         True         False         False          True
# 27                  0        False         False         False          True
# 28                  1        False         False         False          True
# 29                  2        False         False         False          True
# 30                  2         True         False         False          True
# 31                  3         True         False         False          True
# 32                  1        False         False         False          True
# 33                  2        False         False         False          True
# 34                  1         True         False         False          True
# 35                  3         True         False         False          True
# 36                  0         True         False         False          True
# 37                  5        False         False         False          True
# 38                  1         True         False         False          True
# 39                 45         True         False         False          True
# 40                 40         True         False         False          True
# 41                  3        False         False         False          True
# 42                  2         True         False         False          True
# 43                  1        False         False         False          True
# 44                  4         True         False         False          True
# 45                  0        False         False         False          True
