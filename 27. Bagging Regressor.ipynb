# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import Ridge, ElasticNet
from sklearn.ensemble import BaggingRegressor
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
import os
os.chdir("D:/Training/Academy/ML(Python)/Datasets")

# %%
boston = pd.read_csv("Boston.csv")
X, y = boston.drop('medv', axis=1), boston['medv']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# %%
ridge = Ridge()
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)
print( mean_absolute_error(y_test, y_pred) )
# Out:
# 3.071006801570943

# %%
el = ElasticNet()
el.fit(X_train, y_train)
y_pred = el.predict(X_test)
print( mean_absolute_error(y_test, y_pred) )
# Out:
# 3.4080058775996536

# %%
dtr = DecisionTreeRegressor(random_state=25)
dtr.fit(X_train, y_train)
y_pred = dtr.predict(X_test)
print( mean_absolute_error(y_test, y_pred) )
# Out:
# 2.9348684210526317

# %%
bagg = BaggingRegressor(random_state=25, estimator=ridge, n_estimators=15)
bagg.fit(X_train, y_train)
y_pred = bagg.predict(X_test)
print( mean_absolute_error(y_test, y_pred) )
# Out:
# 3.1069338654068606

# %%
bagg = BaggingRegressor(random_state=25, estimator=el, n_estimators=15)
bagg.fit(X_train, y_train)
y_pred = bagg.predict(X_test)
print( mean_absolute_error(y_test, y_pred) )
# Out:
# 3.4270531031532863

# %%
bagg = BaggingRegressor(random_state=25, estimator=dtr, n_estimators=15)
bagg.fit(X_train, y_train)
y_pred = bagg.predict(X_test)
print( mean_absolute_error(y_test, y_pred) )
# Out:
# 2.325438596491228

# %%
scores = []
for n in [10, 15, 25, 50, 100, 150, 200]:
    bagg = BaggingRegressor(random_state=25, estimator=dtr, n_estimators=n)
    bagg.fit(X_train, y_train)
    y_pred = bagg.predict(X_test)
    scores.append([n, mean_absolute_error(y_test, y_pred)] )
df_scores = pd.DataFrame( scores, columns=['n_estimators', 'score'] )
df_scores.sort_values('score')
# Out:
#    n_estimators     score
# 5           150  2.211583
# 6           200  2.211842
# 4           100  2.240322
# 3            50  2.270316
# 2            25  2.284553
# 0            10  2.320461
# 1            15  2.325439
