# %%
import os
os.chdir("D:/Training/Academy/ML(Python)/Datasets")
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df = pd.read_csv("monthly-milk-production-pounds-p.csv")
df.head()
# Out:
#      Month  Milk
# 0  1962-01   589
# 1  1962-02   561
# 2  1962-03   640
# 3  1962-04   656
# 4  1962-05   727

# %%
df.plot()
plt.show()

# %%
series = df['Milk']
result = seasonal_decompose(series, model='additive',period=12)
result.plot()
plt.title("Additive Decomposition")
plt.show()

# %%
result = seasonal_decompose(series, model='multiplicative',  period=12)
result.plot()
plt.title("Multiplicative Decomposition")
plt.show()

# %%
airpassengers = pd.read_csv("AirPassengers.csv")
airpassengers.head()
# Out:
#      Month  Passengers
# 0  1949-01         112
# 1  1949-02         118
# 2  1949-03         132
# 3  1949-04         129
# 4  1949-05         121

# %%
ausgas = pd.read_csv("AusGas.csv")
series = ausgas['GasProd']
result = seasonal_decompose(series, model='additive',period=12)
result.plot()
plt.title("Additive Decomposition")
plt.show()

# %% [markdown]
# Resample to *Quarterly*

# %%
df = pd.read_csv("monthly-milk-production-pounds-p.csv", index_col=0)
df.index = pd.to_datetime( df.index ).to_period("M")
df_qtr = df.resample('Q').sum()
df_qtr.plot()
plt.title("Quarterly Total of Milk Production")
plt.show()

# %%
df_qtr = df.resample('Q').mean()
df_qtr.plot()
plt.title("Quarterly Average of Milk Production")
plt.show()

# %% [markdown]
# ### Centered Moving Average / Rolling Mean

# %%
df = pd.read_csv("monthly-milk-production-pounds-p.csv")

# %%
span=3
fcast = df['Milk'].rolling(span,center=True).mean()
plt.plot(df['Milk'], label='Data')
plt.plot(fcast, label='Centered Rolling Mean')
plt.legend(loc='best')
plt.show()
